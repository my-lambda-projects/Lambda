// %%
players=("A","B","C")

// %%
players
// Out:
// ('A', 'B', 'C')

// %%
print(players)
// Out:
// ('A', 'B', 'C')

// %%
print("players")
// Out:
// players

// %%
players.append("D")
// Out:
// Error: [object Object]

// %%
players.extend("D")
// Out:
// Error: [object Object]

// %%
players[0]
// Out:
// 'A'

// %%
players[:]
// Out:
// ('A', 'B', 'C')

// %%
players[-1]
// Out:
// 'C'

// %%
alfa=players

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
type(alfa)
// Out:
// Error: [object Object]

// %%
players.list
// Out:
// Error: [object Object]

// %%
z=list(players)

// %%
z
// Out:
// ['A', 'B', 'C']

// %%
z=alfa

// %%
players
// Out:
// ('A', 'B', 'C')

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
z
// Out:
// ('A', 'B', 'C')

// %%
players=list(alfa)
// Out:
// Error: [object Object]

// %%
players
// Out:
// Error: [object Object]

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
players.append("D")

// %%
players
// Out:
// ['A', 'B', 'C', 'D']

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
alfa.append("E")
// Out:
// Error: [object Object]

// %% [markdown]
// ### shallow copy

// %%
players
// Out:
// Error: [object Object]

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
players=alfa

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
players=list(alfa)

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
players
// Out:
// ['A', 'B', 'C']

// %%
players.append("E")

// %%
players
// Out:
// ['A', 'B', 'C', 'E']

// %%
alfa
// Out:
// ('A', 'B', 'C')

// %%
alfa.append("G")
// Out:
// Error: [object Object]

// %% [markdown]
// ### Deep Copy

// %%
players=(alfa)
// Out:
// Error: [object Object]

// %%
players
// Out:
// ['A', 'B', 'C', 'E']

// %%
team=["1","2","3","4",]

// %%
team
// Out:
// ['1', '2', '3', '4']

// %%
players=copy.deepcopy(team)
// Out:
// Error: [object Object]

// %%
team=copy.deepcopy(AAA)
// Out:
// Error: [object Object]

// %%
AAA=copy.deepcopy(team)
// Out:
// Error: [object Object]

// %%
AB=["1","2","3"]

// %%
CD=["a","b","c"]

// %%
Z=list(AB)

// %%
Z
// Out:
// ['1', '2', '3']

// %%
AB.append("4")

// %%
AB
// Out:
// ['1', '2', '3', '4']

// %%
Z
// Out:
// ['1', '2', '3']

// %%
import copy

// %%
E=copy.deepcopy(AB)

// %%
E
// Out:
// ['1', '2', '3', '4']

// %%
AB.append(4)

// %%
AB
// Out:
// ['1', '2', '3', '4', 4]

// %%
E
// Out:
// ['1', '2', '3', '4']

// %%
E.append(5)

// %%
F=tuple(E)

// %%
E
// Out:
// ['1', '2', '3', '4', 5]

// %%
F
// Out:
// ('1', '2', '3', '4', 5)
